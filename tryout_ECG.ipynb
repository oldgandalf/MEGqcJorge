# %%
#%% TRY TO SAVE DERIVATIVE FROM BIDS DATASET HERE:
from meg_qc import make_derivative_meg_qc
config_file_name = 'settings.ini'
raw, QC_derivs, QC_simple, df_head_pos, head_pos = make_derivative_meg_qc(config_file_name)

raw

#NFFT NPER SEG 1000
# Out:
# Using matplotlib as 2D backend.
# ___MEG QC___:  list_of_subs ['emptyroom', 'mind002', 'mind003', 'mind004', 'mind006', 'mind007', 'mind008', 'mind009', 'mind010']
# ___MEG QC___:  Take SID:  emptyroom
# ___MEG QC___:  Starting initial processing...
# Opening raw data file /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/sub-emptyroom/ses-19121026/meg/sub-emptyroom_ses-19121026_task-noise_meg.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 37380 ... 592739 =     20.849 ...   330.606 secs
# Ready.
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# Reading 0 ... 322719  =      0.000 ...   180.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth lowpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 100.00 Hz: -6.02 dB
#
# 9 events found
# Event IDs: [ 1  3  7 15 31]
# 9 events found
# Event IDs: [ 1  3  7 15 31]
# ___MEG QC___:  Stimulus channels detected: ['STI 001', 'STI 002', 'STI 003', 'STI 004', 'STI 005', 'STI 006', 'STI 014', 'STI 015', 'STI 016']
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# ___MEG QC___:  No events with set minimum duration were found using all stimulus channels. No epoching can be done. Try different event duration in config file.
# ___MEG QC___:  No ECG channels found is this data set. Attempting to reconstruct ECG data from magnetometers...
# ___MEG QC___:  Starting PSD...
# Effective window size : 0.558 (s)
# /Volumes/MAIN DATA/Users/evgeniiagapontseva/Local/MEG-QC-code/Functions/PSD_meg_qc.py:618: RuntimeWarning: joblib not installed. Cannot run in parallel.
#   psds[m_or_g], freqs[m_or_g] = raw.compute_psd(method=method, fmin=psd_params['freq_min'], fmax=psd_params['freq_max'], picks=m_or_g, n_jobs=-1, n_fft=psd_params['n_fft'], n_per_seg=psd_params['n_per_seg']).get_data(return_freqs=True)
# ___MEG QC___:  Magnetometers
# ___MEG QC___:
# Average absolute power per band:
# ___MEG QC___:  delta 1.657013004022727e-14
# ___MEG QC___:  theta 1.053356737566644e-14
# ___MEG QC___:  alpha 1.0420688568307709e-14
# ___MEG QC___:  beta 1.0797404672917147e-13
# ___MEG QC___:  gamma 3.1284303255469293e-13
# ___MEG QC___:
# Average relative power per band:
# ___MEG QC___:  delta 0.03251745845984811
# ___MEG QC___:  theta 0.020545178228929584
# ___MEG QC___:  alpha 0.02037309591534455
# ___MEG QC___:  beta 0.2116619962102834
# ___MEG QC___:  gamma 0.6129347772112945
# ___MEG QC___:
# Average power/freq per band:
# ___MEG QC___:  delta 8.285065020113634e-15
# ___MEG QC___:  theta 5.26678368783322e-15
# ___MEG QC___:  alpha 5.2103442841538546e-15
# ___MEG QC___:  beta 1.0797404672917148e-14
# ___MEG QC___:  gamma 8.0216162193511e-15
# ___MEG QC___:  Finished PSD. --- Execution 1.530789852142334 seconds ---
# Embedding : jquery-3.6.0.min.js
# Embedding : bootstrap.bundle.min.js
# Embedding : bootstrap.min.css
# Embedding : bootstrap-table/bootstrap-table.min.js
# Embedding : bootstrap-table/bootstrap-table.min.css
# Embedding : bootstrap-table/bootstrap-table-copy-rows.min.js
# Embedding : bootstrap-table/bootstrap-table-export.min.js
# Embedding : bootstrap-table/tableExport.min.js
# Embedding : bootstrap-icons/bootstrap-icons.mne.min.css
# Embedding : highlightjs/highlight.min.js
# Embedding : highlightjs/atom-one-dark-reasonable.min.css
# ___MEG QC___:  Take SID:  mind002
# ___MEG QC___:  Starting initial processing...
# Opening raw data file /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/sub-mind002/ses-01/meg/sub-mind002_ses-01_task-auditory_meg.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 63240 ... 1656639 =     50.592 ...  1325.311 secs
# Ready.
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# Reading 0 ... 225000  =      0.000 ...   180.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth lowpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 100.00 Hz: -6.02 dB
#
# 119 events found
# Event IDs: [ 5  7  9 11 17 19 33 35]
# 119 events found
# Event IDs: [ 5  7  9 11 17 19 33 35]
# ___MEG QC___:  Stimulus channels detected: ['STI 001', 'STI 002', 'STI 003', 'STI 004', 'STI 005', 'STI 006', 'STI 014', 'STI 015', 'STI 016']
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# ___MEG QC___:  No events with set minimum duration were found using all stimulus channels. No epoching can be done. Try different event duration in config file.
# ___MEG QC___:  No ECG channels found is this data set. Attempting to reconstruct ECG data from magnetometers...
# ___MEG QC___:  Starting PSD...
# Effective window size : 0.800 (s)
# /Volumes/MAIN DATA/Users/evgeniiagapontseva/Local/MEG-QC-code/Functions/PSD_meg_qc.py:618: RuntimeWarning:
#
# joblib not installed. Cannot run in parallel.
# ___MEG QC___:  Magnetometers
# ___MEG QC___:
# Average absolute power per band:
# ___MEG QC___:  delta 1.230047333566302e-13
# ___MEG QC___:  theta 1.0963148076899674e-13
# ___MEG QC___:  alpha 1.4557869755838702e-13
# ___MEG QC___:  beta 5.054003982657732e-13
# ___MEG QC___:  gamma 4.875237400458816e-13
# ___MEG QC___:
# Average relative power per band:
# ___MEG QC___:  delta 0.07988825188718325
# ___MEG QC___:  theta 0.07056699130890758
# ___MEG QC___:  alpha 0.09047767418903274
# ___MEG QC___:  beta 0.3256602012059572
# ___MEG QC___:  gamma 0.3224943175904467
# ___MEG QC___:
# Average power/freq per band:
# ___MEG QC___:  delta 4.1001577785543394e-14
# ___MEG QC___:  theta 3.654382692299891e-14
# ___MEG QC___:  alpha 4.8526232519462343e-14
# ___MEG QC___:  beta 3.369335988438488e-14
# ___MEG QC___:  gamma 8.55304807098038e-15
# ___MEG QC___:  Finished PSD. --- Execution 0.7706770896911621 seconds ---
# Embedding : jquery-3.6.0.min.js
# Embedding : bootstrap.bundle.min.js
# Embedding : bootstrap.min.css
# Embedding : bootstrap-table/bootstrap-table.min.js
# Embedding : bootstrap-table/bootstrap-table.min.css
# Embedding : bootstrap-table/bootstrap-table-copy-rows.min.js
# Embedding : bootstrap-table/bootstrap-table-export.min.js
# Embedding : bootstrap-table/tableExport.min.js
# Embedding : bootstrap-icons/bootstrap-icons.mne.min.css
# Embedding : highlightjs/highlight.min.js
# Embedding : highlightjs/atom-one-dark-reasonable.min.css
# ___MEG QC___:  Take SID:  mind003
# ___MEG QC___:  Starting initial processing...
# Opening raw data file /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/sub-mind003/ses-01/meg/sub-mind003_ses-01_task-auditory_meg.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 141360 ... 1711199 =    113.088 ...  1368.959 secs
# Ready.
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# Reading 0 ... 225000  =      0.000 ...   180.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth lowpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 100.00 Hz: -6.02 dB
#
# 124 events found
# Event IDs: [ 5  7  9 11 17 19 33 35]
# 124 events found
# Event IDs: [ 5  7  9 11 17 19 33 35]
# ___MEG QC___:  Stimulus channels detected: ['STI 001', 'STI 002', 'STI 003', 'STI 004', 'STI 005', 'STI 006', 'STI 014', 'STI 015', 'STI 016']
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# ___MEG QC___:  No events with set minimum duration were found using all stimulus channels. No epoching can be done. Try different event duration in config file.
# ___MEG QC___:  Starting PSD...
# Effective window size : 0.800 (s)
# /Volumes/MAIN DATA/Users/evgeniiagapontseva/Local/MEG-QC-code/Functions/PSD_meg_qc.py:618: RuntimeWarning:
#
# joblib not installed. Cannot run in parallel.
# ___MEG QC___:  Magnetometers
# ___MEG QC___:
# Average absolute power per band:
# ___MEG QC___:  delta 1.5447510125618992e-13
# ___MEG QC___:  theta 1.0556722171113057e-13
# ___MEG QC___:  alpha 9.319282409046474e-14
# ___MEG QC___:  beta 4.431626800192079e-13
# ___MEG QC___:  gamma 4.4839136595545154e-13
# ___MEG QC___:
# Average relative power per band:
# ___MEG QC___:  delta 0.10956040943660725
# ___MEG QC___:  theta 0.07534222459425165
# ___MEG QC___:  alpha 0.06635062195983904
# ___MEG QC___:  beta 0.3165961554834759
# ___MEG QC___:  gamma 0.32181198205282674
# ___MEG QC___:
# Average power/freq per band:
# ___MEG QC___:  delta 5.1491700418729975e-14
# ___MEG QC___:  theta 3.518907390371019e-14
# ___MEG QC___:  alpha 3.1064274696821584e-14
# ___MEG QC___:  beta 2.9544178667947194e-14
# ___MEG QC___:  gamma 7.866515192200905e-15
# ___MEG QC___:  Finished PSD. --- Execution 0.7801227569580078 seconds ---
# Embedding : jquery-3.6.0.min.js
# Embedding : bootstrap.bundle.min.js
# Embedding : bootstrap.min.css
# Embedding : bootstrap-table/bootstrap-table.min.js
# Embedding : bootstrap-table/bootstrap-table.min.css
# Embedding : bootstrap-table/bootstrap-table-copy-rows.min.js
# Embedding : bootstrap-table/bootstrap-table-export.min.js
# Embedding : bootstrap-table/tableExport.min.js
# Embedding : bootstrap-icons/bootstrap-icons.mne.min.css
# Embedding : highlightjs/highlight.min.js
# Embedding : highlightjs/atom-one-dark-reasonable.min.css
# ___MEG QC___:  Take SID:  mind004
# ___MEG QC___:  Starting initial processing...
# Opening raw data file /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/sub-mind004/ses-01/meg/sub-mind004_ses-01_task-auditory_meg.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 37200 ... 1613239 =     29.760 ...  1290.591 secs
# Ready.
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# Reading 0 ... 225000  =      0.000 ...   180.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth lowpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 100.00 Hz: -6.02 dB
#
# 121 events found
# Event IDs: [ 1  5  7  9 11 17 19 33 35]
# 121 events found
# Event IDs: [ 1  5  7  9 11 17 19 33 35]
# ___MEG QC___:  Stimulus channels detected: ['STI 001', 'STI 002', 'STI 003', 'STI 004', 'STI 005', 'STI 006', 'STI 014', 'STI 015', 'STI 016']
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# ___MEG QC___:  No events with set minimum duration were found using all stimulus channels. No epoching can be done. Try different event duration in config file.
# ___MEG QC___:  Starting PSD...
# Effective window size : 0.800 (s)
# /Volumes/MAIN DATA/Users/evgeniiagapontseva/Local/MEG-QC-code/Functions/PSD_meg_qc.py:618: RuntimeWarning:
#
# joblib not installed. Cannot run in parallel.
# ___MEG QC___:  Magnetometers
# ___MEG QC___:
# Average absolute power per band:
# ___MEG QC___:  delta 1.319910162858265e-13
# ___MEG QC___:  theta 1.0902099213267257e-13
# ___MEG QC___:  alpha 1.4625697762265527e-13
# ___MEG QC___:  beta 7.966407562702346e-13
# ___MEG QC___:  gamma 6.303626112682878e-13
# ___MEG QC___:
# Average relative power per band:
# ___MEG QC___:  delta 0.06616385568461297
# ___MEG QC___:  theta 0.05432279808315899
# ___MEG QC___:  alpha 0.07231299454645948
# ___MEG QC___:  beta 0.39290191375879097
# ___MEG QC___:  gamma 0.3187542730755901
# ___MEG QC___:
# Average power/freq per band:
# ___MEG QC___:  delta 4.399700542860883e-14
# ___MEG QC___:  theta 3.6340330710890856e-14
# ___MEG QC___:  alpha 4.8752325874218424e-14
# ___MEG QC___:  beta 5.3109383751348977e-14
# ___MEG QC___:  gamma 1.10589931801454e-14
# ___MEG QC___:  Finished PSD. --- Execution 0.8553500175476074 seconds ---
# Embedding : jquery-3.6.0.min.js
# Embedding : bootstrap.bundle.min.js
# Embedding : bootstrap.min.css
# Embedding : bootstrap-table/bootstrap-table.min.js
# Embedding : bootstrap-table/bootstrap-table.min.css
# Embedding : bootstrap-table/bootstrap-table-copy-rows.min.js
# Embedding : bootstrap-table/bootstrap-table-export.min.js
# Embedding : bootstrap-table/tableExport.min.js
# Embedding : bootstrap-icons/bootstrap-icons.mne.min.css
# Embedding : highlightjs/highlight.min.js
# Embedding : highlightjs/atom-one-dark-reasonable.min.css
# ___MEG QC___:  Take SID:  mind006
# ___MEG QC___:  Starting initial processing...
# Opening raw data file /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/sub-mind006/ses-01/meg/sub-mind006_ses-01_task-auditory_meg.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 85560 ... 1651679 =     68.448 ...  1321.343 secs
# Ready.
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# Reading 0 ... 225000  =      0.000 ...   180.000 secs...
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 1e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth lowpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 100.00 Hz: -6.02 dB
#
# 122 events found
# Event IDs: [1 2 3 4 5 6 7 8]
# 122 events found
# Event IDs: [1 2 3 4 5 6 7 8]
# ___MEG QC___:  Stimulus channels detected: ['STI 001', 'STI 002', 'STI 003', 'STI 004', 'STI 005', 'STI 006', 'STI 014', 'STI 015', 'STI 016']
# Removing projector <Projection | PCA-v1, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v2, active : False, n_channels : 102>
# Removing projector <Projection | PCA-v3, active : False, n_channels : 102>
# ___MEG QC___:  No events with set minimum duration were found using all stimulus channels. No epoching can be done. Try different event duration in config file.
# ___MEG QC___:  Starting PSD...
# Effective window size : 0.800 (s)
# /Volumes/MAIN DATA/Users/evgeniiagapontseva/Local/MEG-QC-code/Functions/PSD_meg_qc.py:618: RuntimeWarning:
#
# joblib not installed. Cannot run in parallel.
# ___MEG QC___:  Magnetometers
# ___MEG QC___:
# Average absolute power per band:
# ___MEG QC___:  delta 1.421317336062897e-13
# ___MEG QC___:  theta 9.048828614210718e-14
# ___MEG QC___:  alpha 6.980014445954746e-14
# ___MEG QC___:  beta 3.9546329909785115e-13
# ___MEG QC___:  gamma 5.161233577928301e-13
# ___MEG QC___:
# Average relative power per band:
# ___MEG QC___:  delta 0.10490419264572408
# ___MEG QC___:  theta 0.0670464577113565
# ___MEG QC___:  alpha 0.05179626950494549
# ___MEG QC___:  beta 0.294321477569491
# ___MEG QC___:  gamma 0.38732009243719273
# ___MEG QC___:
# Average power/freq per band:
# ___MEG QC___:  delta 4.7377244535429905e-14
# ___MEG QC___:  theta 3.016276204736906e-14
# ___MEG QC___:  alpha 2.3266714819849154e-14
# ___MEG QC___:  beta 2.636421993985674e-14
# ___MEG QC___:  gamma 9.054795750751407e-15
# ___MEG QC___:  Finished PSD. --- Execution 0.8996632099151611 seconds ---
# Embedding : jquery-3.6.0.min.js
# Embedding : bootstrap.bundle.min.js
# Embedding : bootstrap.min.css
# Embedding : bootstrap-table/bootstrap-table.min.js
# Embedding : bootstrap-table/bootstrap-table.min.css
# Embedding : bootstrap-table/bootstrap-table-copy-rows.min.js
# Embedding : bootstrap-table/bootstrap-table-export.min.js
# Embedding : bootstrap-table/tableExport.min.js
# Embedding : bootstrap-icons/bootstrap-icons.mne.min.css
# Embedding : highlightjs/highlight.min.js
# Embedding : highlightjs/atom-one-dark-reasonable.min.css
# Overwriting existing file.
# Saving report to : /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/derivatives/Meg_QC/sub-emptyroom/sub-emptyroom_ses-19121026_task-noise_desc-REPORT MNE_meg.html
# Overwriting existing file.
# Saving report to : /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/derivatives/Meg_QC/sub-mind002/sub-mind002_ses-01_task-auditory_desc-REPORT MNE_meg.html
# Overwriting existing file.
# Saving report to : /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/derivatives/Meg_QC/sub-mind003/sub-mind003_ses-01_task-auditory_desc-REPORT MNE_meg.html
# Overwriting existing file.
# Saving report to : /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/derivatives/Meg_QC/sub-mind004/sub-mind004_ses-01_task-auditory_desc-REPORT MNE_meg.html
# Overwriting existing file.
# Saving report to : /Volumes/M2_DATA/MEG_QC_stuff/data/from openneuro/ds004107/derivatives/Meg_QC/sub-mind006/sub-mind006_ses-01_task-auditory_desc-REPORT MNE_meg.html
# <Raw | sub-mind006_ses-01_task-auditory_meg.fif, 318 x 1566120 (1252.9 s), ~6.2 MB, data not loaded>
